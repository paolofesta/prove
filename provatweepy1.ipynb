# %% [markdown]
# <a href="https://colab.research.google.com/github/paolofesta/prove/blob/master/provatweepy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import tweepy

# %%
# Variables that contains the credentials to access Twitter API
ACCESS_TOKEN = '1500753981525659655-2OYENj2RBJS753zwIZ9a9zQukiSHY5'
ACCESS_SECRET = 'M1naDc08ZQuWYX7yZV4hRZ8IwH0J5uiraPXNzTe6Py2TL'
CONSUMER_KEY = 'yOKa2wpMnubBCq6pV3XLD8lRL'
CONSUMER_SECRET = 'pDyuUu4ssKWS4PHF4wN2lZ7RjdYQe1yLjBbK745o3vdOoxgtUN'

# %%
# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api

# %%
# Create API object
api = connect_to_twitter_OAuth()

# %%
# tweets from a specific user
Barilla_tweets = api.user_timeline('Barilla')
for tweet in Barilla_tweets:
    print(tweet.text)
# Out:
# First Italian town on this year’s bucket list – we know you have one. Go! 📝
# @JeanneSapp Hello. To fully enjoy our pasta, we would recommend sticking to the best by date featured on the packaging. ❤️🍝
# @bluebutterflyyl @BarillaTurkiye We are so sorry to hear about your experience. If you send us a DM with your name,… https://t.co/oC8OgYvyIy
# When was the last time you cooked as a surprise for someone? Show them a #ASignOfLove! ❤️
# @ArcHeisenberg @ItalianComments We've outgrown this, we promise! No spaghetti was harmed in the process. 🍝
# @soymfm Supporting communities is part of our Mission. We are supplying essential food products to international NG… https://t.co/26Cmjc6xgR
# @Sam201810 Hello. Food is essential for the wellbeing of all people, so we see no reason to discontinue our food production.
# @jasonmantis Hello. Food is essential for the wellbeing of all people, so we see no reason to discontinue our food production.
# @soymfm Hello. Food is essential for the wellbeing of all people, so we see no reason to discontinue our food production.
# Just wondering: why do people keep cutting up spaghetti, @ItalianComments?
# @NeyAb6 @Viviaulac @Fl4mmenwerfer35 @Crohnfighter Hello. After his remarks in 2013, Guido has apologised. He suppor… https://t.co/gKaPZj6iGb
# Italian hacks for something new: add cooking water to your pesto for a creamier result. You're welcome!
# @derpapitem Hello. Barilla pesto sauces are made in Italy with high-quality ingredients. You can read more here: https://t.co/49hxqKjk4L
# @ItsMeAshliB Hello. We appreciate your interest. We currently have more than five pasta cuts in our protein range,… https://t.co/HC6L3sH8Fx
# @totenmond Hello. We fight against homophobia by promoting diversity and inclusion through facts and setting them a… https://t.co/WHHuZYtDPL
# @CharlesTroupin Our boxes are 100% recyclable as paper (even with the window) – modern recycling systems divide pla… https://t.co/OjPvhmIS7d
# @Juliette_Briens @barillagroup Hello, Juliette. We did an internal check and unfortunately, Pesto Alla Calabrese wi… https://t.co/IzYdQIv8sS
# @tazcj @Martina Hi, that's actually not true. Barilla fights homophobia by promoting diversity and inclusion throug… https://t.co/04UbTVWrB1
# @CharlesTroupin Hi! We are committed towards sustainable packaging and have introduced window-less boxes in some co… https://t.co/1ugHn5SxWq
# @MikaelaShiffrin 💪❤

# %%
import numpy as np
import pandas as pd

# %%
# fuction to extract data from tweet object
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
    # loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        text = tweet.text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id, 
                          'text':text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})
    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'text',
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'reply_to_status',
                                           'reply_to_user',
                                           'retweets',
                                           'favorites'])
    return df


df = extract_tweet_attributes(Barilla_tweets)

# %%
df
# Out:
#                tweet_id                                               text  \
# 0   1502335372474433536  First Italian town on this year’s bucket list ...
# 1   1502232929166151681  @JeanneSapp Hello. To fully enjoy our pasta, w...
# 2   1501963133656748032  @bluebutterflyyl @BarillaTurkiye We are so sor...
# 3   1501609899704434695  When was the last time you cooked as a surpris...
# 4   1501234357067042823  @ArcHeisenberg @ItalianComments We've outgrown...
# 5   1500891655259439109  @soymfm Supporting communities is part of our ...
# 6   1500885895523848196  @Sam201810 Hello. Food is essential for the we...
# 7   1500885831657132034  @jasonmantis Hello. Food is essential for the ...
# 8   1500885680347660294  @soymfm Hello. Food is essential for the wellb...
# 9   1500883924481941517  Just wondering: why do people keep cutting up ...
# 10  1500765424723632131  @NeyAb6 @Viviaulac @Fl4mmenwerfer35 @Crohnfigh...
# 11  1499797643622551566  Italian hacks for something new: add cooking w...
# 12  1498708678152798208  @derpapitem Hello. Barilla pesto sauces are ma...
