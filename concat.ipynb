# %% [markdown]
# <a href="https://colab.research.google.com/github/paolofesta/prove/blob/master/concat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
cgil=pd.read_csv('/content/cgil_data')
cgil['sigla']=np.array('CGIL')

# %%
cisl=pd.read_csv('/content/cisl_data')
cisl['sigla']=np.array('CISL')

# %%
uil=pd.read_csv('/content/uil_data')
uil['sigla']=np.array('UIL')

# %%
data=pd.concat([cgil,cisl,uil],ignore_index= True)
data
# Out:
#                  tweet_id                                               text  \
# 0     1524830657712640010  RT @kastatrof: Imaginez.. à qq heures de route...
# 1     1524824670125625345  @cgilnazionale Sembra una supercazzola... prem...
# 2     1524809559851814912  RT @kastatrof: Imaginez.. à qq heures de route...
# 3     1524804096439492612  🟥SOLO LA PACE\n@cgilnazionale partecipa all'ac...
# 4     1524802721789972485  @fpcgil_internaz @fbunational @FpCgilVVF @EPSU...
# ...                   ...                                                ...
# 6854  1521880388322349056  Vomito. Siete tutti, indistintamente patetici....
# 6855  1521880348472324103  RT @UILofficial: Soddisfatti per l’istituzione...
# 6856  1521872405114802176  RT @UILofficial: Soddisfatti per l’istituzione...
# 6857  1521868855324385283  @ToniSerafini @UILofficial Siamo messi meglio ...
# 6858  1521857392136400896  Fate vomitare! Vi dovreste vergognare! Ma arri...
#
# ...

# %%
data.to_csv('data')
