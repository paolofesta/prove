# %% [markdown]
# <a href="https://colab.research.google.com/github/paolofesta/prove/blob/master/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy

# %%
# Variables that contains the credentials to access Twitter API
ACCESS_TOKEN = '1500753981525659655-2OYENj2RBJS753zwIZ9a9zQukiSHY5'
ACCESS_SECRET = 'M1naDc08ZQuWYX7yZV4hRZ8IwH0J5uiraPXNzTe6Py2TL'
CONSUMER_KEY = 'yOKa2wpMnubBCq6pV3XLD8lRL'
CONSUMER_SECRET = 'pDyuUu4ssKWS4PHF4wN2lZ7RjdYQe1yLjBbK745o3vdOoxgtUN'

# %%
# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api

# %%
# Create API object
api = connect_to_twitter_OAuth()

# %%
hashtag_tweets= api.search(q=("#Leclerc","cars","#Verstappen"),tweet_mode='extended',since="2022-3-1") # nella query la , funziona come &

# %%
hashtag_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f6d67686b50>, _json={'created_at': 'Sun Apr 24 15:15:20 +0000 2022', 'id': 1518247225821843456, 'id_str': '1518247225821843456', 'full_text': "For those who are saying It's always the car in Lewis' Case.... It's the same in the case of Max &amp; Charles also... Today's racing is all about the cars #IMOLAGP #Leclerc #Hamilton #F1 #Verstappen #F1JP", 'truncated': False, 'display_text_range': [0, 205], 'entities': {'hashtags': [{'text': 'IMOLAGP', 'indices': [156, 164]}, {'text': 'Leclerc', 'indices': [165, 173]}, {'text': 'Hamilton', 'indices': [174, 183]}, {'text': 'F1', 'indices': [184, 187]}, {'text': 'Verstappen', 'indices': [188, 199]}, {'text': 'F1JP', 'indices': [200, 205]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id
# ...

# %%
for tweet in hashtag_tweets: text = tweet._json["full_text"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-33b061992609> in <module>()
# ----> 1 for tweet in hashtag_tweets: text = tweet._json["full_text"]
#
# TypeError: 'Cursor' object is not iterable

# %%
print(text)
# Out:
# Verstappen, Perez e Norris rivedono l`incidente di Leclerc: ammissione davanti alle telecamere #verstappen #perez #norris #rivedono #lincidente #leclerc #ammissione #telecamere  https://t.co/evaa0nBQEB

# %%
#ora tweet dopo una data

# %%
date_tweets = tweepy.Cursor(api.search,q="#Smartworking",since="2022-1-1",tweet_mode='extended')

# %%
date_tweets

# %%
Date_tweets = api.search(q="#Smartworking",since="2022-1-1",tweet_mode='extended') #risolve il problema di cursor

# %%
Date_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fb2b8048a90>, _json={'created_at': 'Wed Apr 27 16:17:05 +0000 2022', 'id': 1519349928820187140, 'id_str': '1519349928820187140', 'full_text': 'RT @il_tempe: Il senso di perdita di tempo che si ha dopo due anni di #smartworking nello spostarsi da casa in ufficio è incredibile.', 'truncated': False, 'display_text_range': [0, 133], 'entities': {'hashtags': [{'text': 'smartworking', 'indices': [70, 83]}], 'symbols': [], 'user_mentions': [{'screen_name': 'il_tempe', 'name': 'iltempe', 'id': 56496363, 'id_str': '56496363', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'it', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1447233287060180993, 'id_str': '1447233287060180993', 'nam
# ...

# %%
import numpy as np
import pandas as pd

# %%
# fuction to extract data from tweet object
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
    # loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        language= tweet.lang
        text = tweet.full_text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        #reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
       # reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
       
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id,
                           'language':language,
                          'text':text,
                           
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'retweets':retweets,
                          'favorites':favorites})

    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'text',
                                           'language',
                                          
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'retweets',
                                           'favorites'])
    return df


df = extract_tweet_attributes(Date_tweets)
# Out:
#   File "<ipython-input-1-8c65166725f0>", line 18
#     user.mentions_screen_name
#                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
df
# Out:
#                tweet_id                                               text  \
# 0   1519349928820187140  RT @il_tempe: Il senso di perdita di tempo che...
# 1   1519349395430547460  Hard Work vs Smart work\nKeep in Mind\n#smartw...
# 2   1519346578443706371  RT @il_tempe: Il senso di perdita di tempo che...
# 3   1519344487985782785  RT @il_tempe: Il senso di perdita di tempo che...
# 4   1519344229654446081  RT @CinqueGiova: Un mio articolo su @Agenda_Di...
# 5   1519343864913539073  Siamo alla ricerca di un Junior HR Consultant ...
# 6   1519343618942816258  Ricercamy, innovativa società di Ricerca e Sel...
# 7   1519343045233483781  RT @RANDOMFACTS2022: Art+Smart = perfection 👌👏...
# 8   1519340757173387265  RT @il_tempe: Il senso di perdita di tempo che...
# 9   1519339797478842368  Oggi l'HR Manager di #Illumia, Giulia Bernardi...
# 10  1519338951894609920  E come soluzione? Ma si, togliere da un anno a...
# ...

# %%
# fuction to extract data from user object
def extract_user_attributes(user_object):
    # create empty list
    user_list =[]
    # loop through user objects
    for user in user_object:
        user_name= 
        user_list.append({"user_name":user_name})

    # create dataframe   
    df1 = pd.DataFrame(user_list, columns=['user_name'])
    return df1


df1 = extract_user_attributes(Date_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-5720bea44a3e> in <module>()
#      13
#      14
# ---> 15 df1 = extract_user_attributes(Date_tweets)
#
# <ipython-input-96-5720bea44a3e> in extract_user_attributes(user_object)
#       5     # loop through user objects
#       6     for user in user_object:
# ----> 7         user_name= name
#       8         user_list.append({"user_name":user_name})
#       9
#
# NameError: name 'name' is not defined

# %%
df1
# Out:
#                                             user_name
# 0   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 1   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 2   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 3   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 4   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 5   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 6   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 7   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 8   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 9   Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 10  Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 11  Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 12  Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 13  Status(_api=<tweepy.api.API object at 0x7fb2b8...
# 14  Status(_api=<tweepy.api.API object at 0x7fb2b8...
